# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
import json
import plotly.io as pil
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.validators.scatter.marker import SymbolValidator

import plotly.io as pio
pio.renderers.default = 'jupyterlab'

# %%
url = 'https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv'
data = pd.read_csv(url)
data
# Out:
#     Rank                 State Postal  Population
# 0      1               Alabama     AL   4849377.0
# 1      2                Alaska     AK    736732.0
# 2      3               Arizona     AZ   6731484.0
# 3      4              Arkansas     AR   2966369.0
# 4      5            California     CA  38802500.0
# 5      6              Colorado     CO   5355866.0
# 6      7           Connecticut     CT   3596677.0
# 7      8              Delaware     DE    935614.0
# 8      9  District of Columbia     DC    658893.0
# 9     10               Florida     FL  19893297.0
# 10    11               Georgia     GA  10097343.0
# 11    12                Hawaii     HI   1419561.0
# 12    13                 Idaho     ID   1634464.0
# 13    14              Illinois     IL  12880580.0
# 14    15               Indiana     IN   6596855.0
# 15    16                  Iowa     IA   3107126.0
# 16    17                Kansas     KS   2904021.0
# 17    18              Kentucky     KY   4413457.0
# ...

# %%
 fig = go.Figure(
     data = go.Scatter(
     x = data['Postal'],
     y = data['Population'],
     mode = 'markers',
     marker_color = data['Population'],
     text = data['State']
     )
 )
    
fig.update_layout(title = 'USA population')
fig.show()

# %%
fig = go.Figure(
    data = go.Scatter(
    y = np.random.randn(400).cumsum(),
    mode = 'markers',
    marker = dict(
        size = 12,
        color = np.random.randn(400).cumsum(),
        colorscale = 'YlOrRd',
        showscale = True
    )    
    )
)
fig.show()

# %%
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
fig = go.Figure()

config = dict({'scrollZoom':True})

fig.add_trace(
    go.Scatter(
        x = [1,2,3,4,5],
        y = [1,3,5,7,10]
        )
)
fig.show(config= config)

# %%
fig = go.Figure()

config = dict({
    'scrollZoom':True,
    'displayModeBar':True,
    'editable':True

})

fig.add_trace(
    go.Scatter(
        x = [1,2,3,4,5],
        y = [1,3,5,7,10]
        )
)
fig.show(config= config)

# %%
tips = px.data.tips()

fig = px.scatter(
    tips,
    x = 'total_bill',
    y = 'tip',
    facet_col = 'sex',
    width = 800,
    height = 400
)

fig.update_layout(
    margin = dict(l=10, r=20, t=3,b=40),
    paper_bgcolor = 'skyblue'
)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x = np.arange(1,10),
        y = np.arange(10,20)
    )
)

fig.update_layout(
    autosize = False,
    width = 400,
    height = 400,
    margin = dict(l=10, r=20, t=3,b=40),
    paper_bgcolor = 'skyblue'
)

fig.show()

# %%
fig = go.Figure()
fig.add_trace(
    go.Scatter(
        x = np.arange(1,10),
        y = np.arange(10,20)
    )
)

fig.update_layout(
    autosize = False,
    width = 400,
    height = 400,
    margin = dict(l=10, r=20, t=3,b=40, pad=5),
    paper_bgcolor = 'skyblue'
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(
    go.Bar(
        x = ['A','B', 'C', 'D'],
        y = [1,5,15,20],  
    ))

fig.update_layout(
    autosize = False, width = 400, height = 800,
    yaxis = dict(
        title_text = 'Y axis title',
        ticktext = ['T', 'E', 'X', 'TT'],
        tickvals = [1,2,3,4],
        tickmode = 'array',
        titlefont = dict (size = 40)           
    ))

fig.update_yaxes(automargin=True)

fig.show()

# %%
fig = go.Figure(
    go.Scatter(
    x = np.arange(1,10),
    y = np.random.randn(10).cumsum()
    
    )
)
fig.update_layout (
    xaxis = dict(tickmode = 'linear', tick0 =0.8, dtick = 0.4)
)

fig.show()

# %%
fig.update_layout (
    xaxis = dict(tickmode = 'array', tick0 =0.8, dtick = 0.4)
)

fig.show()

# %%
fig.update_layout (
    xaxis = dict(
        tickmode = 'array',
        tickvals = [1,3,5,7,9],
        ticktext = ['one', 'two', 'three', 'four','five'])
)

fig.show()

# %%
fig.update_layout (
    xaxis = dict(tickmode = 'linear', tick0 =0.8, dtick = 0.4),
    yaxis_tickformat = '%'
)

fig.show()

# %%
fig = go.Figure(
    go.Scatter(
    x = np.arange(1,10),
    y = np.random.randint(10000,100000, size =10)
    
    )
)

fig.update_layout(
yaxis = dict (showexponent = 'all', exponentformat = 'e')
)

fig.show()

# %%
url_apple= 'https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv'
aapl = pd.read_csv(url_apple)
aapl
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002     63152400
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001     44891700
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997     37362400
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000     48948400
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000     70974100
# ..          ...         ...         ...         ...         ...          ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
# ...

# %%
fig = go.Figure(
    go.Scatter(
    x = aapl['Date'],
    y = aapl['AAPL.Close']
    )
)
fig.update_layout(xaxis_tickformat = '%Y-%b-%d(%a)')
fig.show()

# %%
fig = go.Figure(
    go.Bar(
    x = ['A', 'B', 'C' ],
    y = [6,7,8]
    )
)

fig.update_xaxes(
showgrid = True,
    ticks = 'outside',
    tickson = 'boundaries',
    ticklen =20

)

fig.show()

# %%
iris = px.data.iris()
fig = px.scatter(iris, x = 'petal_length', y = 'petal_width',
                 color = 'species')
fig.show()

# %%
fig = px.scatter(iris, x = 'petal_length', y = 'petal_width',
                 color = 'species',
                
                labels = {
                    
                    'petal_length':'Petal length(cm)',
                    'petal_width':'Petal width(cm)',
                    'species':'Species'
                }
                )

fig.update_yaxes(nticks=5)
fig.show()

# %%
fig = go.Figure(
    go.Scatter(
    y = [3,1,4,2,5],
    x = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    
    )
)

fig.update_layout(
    title = {
        'text':'Practice',
        'y':0.8,
        'x':0.5,
        'xanchor':'center',
        'yanchor':'top'
        
    }
)

fig.show()

# %%
x = np.arange(50)
fig = px.scatter(x=x, y=x**2, log_x = True, log_y = True)
fig.show()

# %%
fig = px.bar(x= [1,2,3,4,5], y = [10,30,40,20,50])
fig.update_layout(xaxis_type = 'category')
fig.update_yaxes(tick0 = 5, dtick=15)
fig.show()

# %%
tips = px.data.tips()
fig = px.scatter (tips, x = 'total_bill', y ='tip', color = 'sex', facet_row = 'day')
fig.update_xaxes(
    tickangle = 45,
    tickfont = dict (family = 'Arial', color = 'orange', size=14)

)
fig.show()

# %%
fig.update_layout(
    xaxis_showgrid = False, yaxis_showgrid = False
)
fig.show()

# %%
fig.update_layout(
    xaxis_zeroline = False, yaxis_zeroline = False
)
fig.show()

# %%
mirror = True)

# %%
fig = px.histogram(tips, x = 'sex', y = 'tip', histfunc = 'sum', facet_col = 'smoker')
fig.update_xaxes (showgrid = False, linewidth = 3, linecolor = 'red')
fig.update_yaxes (showgrid = False, linewidth = 3, linecolor = 'blue')
fig.show()

# %%
fig = px.histogram(tips, x = 'sex', y = 'tip', histfunc = 'sum', facet_col = 'smoker')
fig.update_xaxes (showgrid = False, linewidth = 3, linecolor = 'red', mirror = True)
fig.update_yaxes (showgrid = False, linewidth = 3, linecolor = 'blue',mirror = True)
fig.show()

# %%
fig = px.histogram(tips, x = 'sex', y = 'tip', histfunc = 'sum', facet_col = 'smoker')
fig.update_xaxes (showgrid = True, gridwidth = 1, gridcolor = 'red')
fig.update_yaxes (showgrid = True, gridwidth = 1, gridcolor = 'orange')
fig.show()

# %%
fig = px.line (y = np.random.randn(10))
fig.update_xaxes(zeroline=True, zerolinewidth =2, zerolinecolor ='orange')
fig.update_yaxes(zeroline=True, zerolinewidth =2, zerolinecolor ='blue')
fig.show()

# %%
fig.update_xaxes(title_text = 'Time')
fig.update_yaxes(title_text = 'Value')
fig.show()

# %%
fig = go.Figure(
    go.Scatter(
    mode = 'lines+markers',
    y = [22,24,25,28,29],
    x = ['Mon','Tue', 'Wed', 'Thr','Fri']
    )
)

fig.update_layout(
    xaxis = dict(
        tickangle =60,
        title_text = 'Week',
        title_font = {'size': 30},
        title_standoff=20
    ),
    yaxis  = dict(
        
        title_text = 'Temp',
        title_font = {'size': 40},
        title_standoff=40
    )    
)

fig.show()

# %%
fig = px.scatter(iris, x = 'petal_length', y = 'petal_width',
                 facet_col = 'species')

fig.update_xaxes(title_font=dict(size=18, family='Courier', color ='orange'))
fig.update_yaxes(title_font=dict(size=18, family='Courier', color ='orange'))

fig.show()

# %%
fig.update_xaxes(range = [0,10])
fig.update_yaxes(range = [0,7])
fig.show()

# %%
fig.update_yaxes(autorange='reversed')
fig.show()

# %%
x = np.linspace(1,300,40)

fig = px.scatter(x =x, y =x**2, log_x = True, log_y = True, range_x=[0.5,300])
fig.show()

# %%
fig.update_xaxes(type = 'log', range = [np.log10(0.5), np.log10(350)])
fig.update_yaxes(type = 'log')
fig.show()

# %%
fig = px.scatter (tips, x = 'total_bill', y ='tip', color = 'sex', facet_col = 'time',
                 symbol = 'smoker',
                 labels = {'sex': 'Gender', 'smoker':'Smokers'})
fig.show()

# %%
fig.update_layout(showlegend=False)
fig.show()

# %%
fig.update_layout(showlegend=True,
                 legend =dict(yanchor = 'top', y=0.96, xanchor='left', x = 0.02))

fig.show()

# %%
fig.update_layout(legend =dict(yanchor = 'bottom', y=1.1, xanchor='right', x = 1, orientation = 'h'))

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x = np.arange(1,10),
    y = np.random.randn(10)+1,
    name = "Postive",
    showlegend = False

))

fig.add_trace(go.Scatter(
    x = np.arange(1,10),
    y = np.random.randn(10)-1,
    name = "Negative",
    visible = 'legendonly'

))

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x = np.arange(1,10),
    y = np.random.randn(10)+1,
    mode = "markers",
    marker = {'size':10}

))

fig.add_trace(go.Scatter(
    x = np.arange(1,10),
    y = np.random.randn(10)-1,
    mode = "markers",
    marker = {'size':30}

))

fig.update_layout(legend = {'itemsizing':'constant'})

fig.show()

# %%
x = np.arange(1,10,5)

y1 = np.random.randn(5)
y2 = np.random.randn(5).cumsum()

fig = make_subplots(rows=2, cols=2,
                   
                   sepcs = [
                       [{'secondary_y':True},{'secondary_y':True}],
                       [{'secondary_y':True},{'secondary_y':True}]                     
                   ]                   
                   )

fig.add_trace(
    go.Scatter(x=x, y=y1, name = 'yaxis1 data'),
    row=1 , col=1, secondary_y = False
)

fig.add_trace(
    go.Scatter(x=x, y=y2, name = 'yaxis2 data'),
    row=1 , col=1, secondary_y = True
)

fig.add_trace(
    go.Scatter(x=x, y=y1, name = 'yaxis3 data'),
    row=1 , col=2, secondary_y = False
)

fig.add_trace(
    go.Scatter(x=x, y=y2, name = 'yaxis4 data'),
    row=1 , col=2, secondary_y = True
)

fig.add_trace(
    go.Scatter(x=x, y=y1, name = 'yaxis5 data'),
    row=2 , col=1, secondary_y = False
)

fig.add_trace(
    go.Scatter(x=x, y=y2, name = 'yaxis6 data'),
    row=2 , col=1, secondary_y = True
)

fig.add_trace(
    go.Scatter(x=x, y=y1, name = 'yaxis7 data'),
    row=2 , col=2, secondary_y = False
)

fig.add_trace(
    go.Scatter(x=x, y=y2, name = 'yaxis8 data'),
    row=2 , col=2, secondary_y = True
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-0cf594a85225> in <module>
#       4 y2 = np.random.randn(5).cumsum()
#       5
# ----> 6 fig = make_subplots(rows=2, cols=2,
#       7
#       8                    sepcs = [
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/subplots.py in make_subplots(rows, cols, shared_xaxes, shared_yaxes, start_cell, print_grid, horizontal_spacing, vertical_spacing, subplot_titles, column_widths, row_heights, specs, insets, column_titles, row_titles, x_title, y_title, figure, **kwargs)
#     350
#     351     if kwargs:
# --> 352         raise TypeError(
#     353             "make_subplots() got unexpected keyword argument(s): {}".format(
#     354                 list(kwargs)
#
# TypeError: make_subplots() got unexpected keyword argument(s): ['sepcs']
