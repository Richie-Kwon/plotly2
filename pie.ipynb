# %%
import numpy as np
import pandas as pd
from urllib.request import urlopen
import json
import plotly.io as pil
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.validators.scatter.marker import SymbolValidator

import plotly.io as pio
pio.renderers.default = 'jupyterlab'

# %%
gapminder = px.data.gapminder()
fig = px.pie(gapminder, values = 'pop', names = 'country')
fig.show()

# %%
fig = px.pie(gapminder, values = 'pop', names = 'country',
            hover_data=['lifeExp'], labels = {'lifeExp':'life expectancy'})

fig.update_traces (textposition = 'inside', textinfo = 'percent+label')
fig.show()

# %%
tips = px.data.tips()

fig = px.pie(tips, values = 'tip', names = 'day')
fig.show()

# %%
tips = px.data.tips()

fig = px.pie(tips, values = 'tip', names = 'day',
            color_discrete_sequence = px.colors.sequential.Viridis)
fig.show()

# %%
tips = px.data.tips()

fig = px.pie(tips, values = 'tip', names = 'day',
            color_discrete_sequence = px.colors.sequential.Viridis,
            hole = 0.4)
fig.show()

# %%
data = dict (

    character = ['Abi simpson', 'Simpson', 'Bobby Simpson', 'Bart', 'Maggie'],
    parent = ['', 'Abi simpson', 'Abi simpson', 'Simpson', 'Simpson'],
    value = [70,55,50,14,10]
)
fig  = px.sunburst(
data, names = 'character', parents = 'parent', values = 'value'
)
fig.show()

# %%
wind = px.data.wind()
wind
# Out:
#     direction strength  frequency
# 0           N      0-1        0.5
# 1         NNE      0-1        0.6
# 2          NE      0-1        0.5
# 3         ENE      0-1        0.4
# 4           E      0-1        0.4
# ..        ...      ...        ...
# 123       WSW       6+        0.1
# 124         W       6+        0.9
# 125       WNW       6+        2.2
# 126        NW       6+        1.5
# 127       NNW       6+        0.2
#
# [128 rows x 3 columns]

# %%
fig = px.scatter_polar(wind, r = 'frequency', theta = 'direction')
fig.show()

# %%
fig = px.scatter_polar(wind, r = 'frequency', theta = 'direction',
                      color = 'strength', symbol = 'strength', size = 'frequency',
                      color_discrete_sequence = px.colors.sequential.Blues_r)
fig.show()

# %%
fig = px.line_polar(wind, r = 'frequency', theta = 'direction',
                      color = 'strength', line_close = True, template = 'plotly_dark',
                      color_discrete_sequence = px.colors.sequential.Blues_r)
fig.show()

# %%
fig = px.bar_polar(wind, r = 'frequency', theta = 'direction',
                      color = 'strength', template = 'plotly_dark',
                      color_discrete_sequence = px.colors.sequential.Blues_r)
fig.show()
